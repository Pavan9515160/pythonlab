# %% [markdown]
# <a href="https://colab.research.google.com/github/Pavan9515160/pythonlab/blob/main/week2/pythonlabweek2_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#find the greatest of three numbers
a=int(input("enter first number"))
b=int(input("enter second number"))
c=int(input("enter third number"))
if a>b and a>c :
  print(f"{a} is bigger")
elif b>a and b>c:
  print(f"{b} is bigger")
else:
  print(f"{c} is bigger")
# Out:
# enter first number3
# enter second number4
# enter third number5
# 5 is bigger

# %%
a=int(input())
b=int(input())
print(a,b)
a,b=b,a
print(a,b)
# Out:
# 5
# 3
# 5 3
# 3 5

# %%
a=int(input())
b=int(input())
c=complex(a,b)
print(c)
# Out:
# 5
# 3
# (5+3j)

# %%
n=int(input())
for()
