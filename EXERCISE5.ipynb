# %% [markdown]
# <a href="https://colab.research.google.com/github/Pavan9515160/pythonlab/blob/main/EXERCISE5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print the all methods
a="hello world"
b=a.split()
c=" pavan "
print(b)
print(" ".join(b))
print(a.upper())
print(a.lower())
print(c.strip())
print(a.replace("world","pavan"))
print(a.count("o"))
print(a.find("l"))
# Out:
# ['hello', 'world']
# hello world
# HELLO WORLD
# hello world
# pavan
# hello pavan
# 2
# 2

# %%
#program that count the no. of vowels
a=input()
b=a.lower()
c="aeiou"
count=0
for i in b:
  if i in c:
    count=count+1
print(count)
# Out:
# raghu ram
# 3

# %%
#print if the substring is present or not
